# %%
class Node:
    def __init__(self,val):
        self.val=val
        self.next=None

# %%
class Sol:
    def __init__(self):
        self.head=None
        self.size=0
    def add(self,value):
        new_node=Node(value)
        if self.head ==None:
            self.head=new_node
        else:
            new_node.next=self.head
            self.head=new_node
            
    def isDivision(self,ll):
        slow=0
        fast=0
        while fast<len(ll) and fast+1 <len(ll) != None:
            slow+=1
            fast+=2
            print("Slow",ll.val)
            print("fast",ll.val if fast else None)

# %%
s=Sol()

# %%
s.add(1)
s.add(2)
s.add(3)
s.add(4)
s.add(5)

# %%
s.isDivision([2,3,4,6,7])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 s.isDivision([2,3,4,6,7])
#
# Cell In[6], line 19, in Sol.isDivision(self, ll)
#      17 slow+=1
#      18 fast+=2
# ---> 19 print("Slow",ll.slow)
#      20 print("fast",ll.fast if fast else None)
#
# AttributeError: 'list' object has no attribute 'slow'
