# %%
class Node:
    def __init__(self,value):
        self.data = value
        self.next = None

# %%
class Stack:
    def __init__(self):
        self.top = None
        self.n=0

    def isEmpty(self):
        return self.top == None

    def push(self,value):

        new_node = Node(value)

        new_node.next = self.top

        self.top = new_node
        self.n =self.n +1

    def traverse(self):
        temp = self.top

        while temp != None:
            print(temp.data)
            temp = temp.next

    def peek(self):
         if self.isEmpty():
             return 'Empty stack'
         else:
             return self.top.data

    def pop(self):
         if (self.isEmpty()):
             return 'Empty stack'
         else:
             popped = self.top.data
             self.top = self.top.next
             self.n = self.n -1
             
         return popped 

    def size(self):
        return self.n

    def StringReversal(self,string):
        s=Stack()
        for ch in string:
            s.push(ch)

        res= ""

        while not (s.isEmpty()) :
            res = res + s.pop() 
            
        return res    


    def text_editor(self,text,pattern):

        u= Stack()
        r= Stack()

        for i in text:
            u.push(i)

        for i in pattern :
            if i == 'u':
                data=u.pop()
                r.push(data)
            else: 
                data=r.pop()
                u.push(data)

        res = ''

        while (not u.isEmpty()):
            res = u.pop() + res

        return (res)

# %%
s=Stack()

# %%
s.isEmpty()
# Out:
# True

# %%
s.push(23)
s.push(8)
s.push(24)
s.push(4)

# %%
s.size()
# Out:
# 4

# %%
s.isEmpty()
# Out:
# False

# %%
s.traverse()
# Out:
# 4
# 24
# 8
# 23

# %%
s.peek()
# Out:
# 4

# %%
s.pop()
# Out:
# 4

# %%
s.traverse()
# Out:
# 24
# 8
# 23

# %%
s.peek()
# Out:
# 24

# %%
s.size()
# Out:
# 3

# %%
s.StringReversal("Ranjeet Singh")
# Out:
# 'hgniS teejnaR'

# %%
s.text_editor('polo','uuuurrr')
# Out:
# 'pol'
