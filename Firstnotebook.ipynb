# %%
print("Ranjeet Singh")
# Out:
# Ranjeet Singh

# %%
print(3+3)
# Out:
# 6

# %%
n1=input(int("Enter a num"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 n1=input(int("Enter a num"))
#
# ValueError: invalid literal for int() with base 10: 'Enter a num'

# %%
n2=input(int("Enter a num"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 n2=input(int("Enter a num"))
#
# ValueError: invalid literal for int() with base 10: 'Enter a num'

# %%
print(f"Sum of numbers are {n1+n2}")
